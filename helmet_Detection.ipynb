# %%
# !git clone https://github.com/its-animay/hat_detection-.git
# Out:
# Cloning into 'hat_detection-'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 60 (delta 36), reused 43 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (60/60), 27.30 KiB | 3.90 MiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %%
# !pip install -r hat_detection-/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 23.1 MB/s eta 0:00:00
# ...

# %%
# %cd /content/hat_detection-/
import sys, os
sys.path.append("/content/hat_detecion-/")
# Out:
# /content/hat_detection-

# %%
# !python -m src.data_setup --train_split 0.8 --seed 42
# Out:
# ...
# Using Colab cache for faster access to the 'helmet-detection' dataset.
# Total XMLs: 764 | Train: 611 | Test: 153
# Categories: ['With Helmet', 'Without Helmet']
# ✅ Dataset setup complete.
# Train folder: /content/hat_detection-/data/train
# Test folder : /content/hat_detection-/data/test

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python -m src.train \
  --epochs 30 --optimizer sgd --scheduler cosine --amp
# Out:
# Using device: cuda
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Num classes (incl background): 3
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100% 160M/160M [00:00<00:00, 198MB/s]
# Epoch 1 Train: 100% 306/306 [02:02<00:00,  2.50it/s, loss=0.255, lr=0.0005]
# ...
